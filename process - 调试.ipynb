# %%
import pandas as pd
import torch
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Input
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from spektral.layers import GATConv
from spektral.transforms import AdjToSpTensor, LayerPreprocess
from spektral.utils import tic, toc
from spektral.data import Dataset , Graph
import os
import networkx as nx
from spektral.data import DisjointLoader
from spektral.data import SingleLoader

from scipy.sparse import coo_matrix
tf.random.set_seed(0)
l2_reg = 2.5e-4

# %%
class MyDataset(Dataset):
    """
    A dataset of five random graphs.
    """
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
    def read(self):
        # We must return a list of Graph objects
        df = pd.read_csv('all.csv').dropna(axis=0,how='any')
        ac = df.groupby(df['standwords_id'])
        output = []
        for i in ac:
            #print(i[1]['standwords_vector'].values[0])
            data_x = i[1]['vector'].apply(lambda x :eval(str(x))).tolist()
            data_x.append(eval(str(i[1]['standwords_vector'].values[0])))
            data_x = np.array(data_x,dtype='float32')
            #print(type(data_x))
            len_1 = len(data_x)
            #data_a = [0]*(len_1-1)*len_1+[1]*(len_1-1)+[0]
            data_a = ([0]*(len_1-1)+[1])*len_1
            data_a = np.array(data_a,dtype='float32').reshape(len_1,-1)
            # print(data_a)
            data_y = [eval(i[1]['label'].tolist()[0])]*len_1
            data_y = np.array(data_y,dtype='float32')
            output.append(
                Graph(x=data_x, a=data_a, y=data_y)
            )
        return output

# %%
dataset = MyDataset()

# %%
len(dataset)
# Out:
# 151

# %%
# Define model

x_in = Input(shape=(dataset.n_node_features,))
a_in = Input(shape=(None,), sparse=True)
#a2_in = Input(shape=(None,), sparse=True)

x_2 = Dropout(0.6)(x_in)
x_2 = GATConv(
    dataset.n_labels,
    attn_heads=1,
    concat_heads=False,
    dropout_rate=0.6,
    activation="softmax",
    kernel_regularizer=l2(l2_reg),
    attn_kernel_regularizer=l2(l2_reg),
    bias_regularizer=l2(l2_reg),
)([x_2, a_in])

# Build model
model = Model(inputs=[x_in, a_in], outputs=x_2)
optimizer = Adam(lr=5e-3)
loss_fn = CategoricalCrossentropy()
acc_fn = CategoricalAccuracy()

# %%
def getnum(x):
    if int(x)>63:
        return int(x)-2
    else:
        return int(x)-1

class MyDataset_2(Dataset):
    """
    A dataset of five random graphs.
    """
    def __init__(self, nodes , y , **kwargs):
        self.nodes = nodes
        self.y = y
        super().__init__(**kwargs)
    def read(self):
        # We must return a list of Graph objects
        edge = pd.read_csv('event_edge.csv',names=['id','from','to'])
        edge['row'] = edge['from'].apply(lambda x:getnum(x))
        edge['col'] = edge['to'].apply(lambda x:getnum(x))
        len_1 = len(edge)
        output = []
        data_x = np.array(self.nodes,dtype='float32')
        row  = np.array(list(edge['row']))
        col  = np.array(list(edge['col']))
        data = np.array([1]*len_1)
        A = coo_matrix((data, (row, col)), shape=(151,151)).tocsr()
        data_a = A.toarray().astype('float32')
        data_y = np.array(self.y,dtype='float32')
        output.append(
            Graph(x=data_x, a=data_a, y=data_y)
        )
        return output

# %%
# Define model_1

x_in_2 = Input(shape=(151,))
a_in_2 = Input(shape=(None,), sparse=True)
#a2_in = Input(shape=(None,), sparse=True)
x2_1 = Dropout(0.6)(x_in_2)
x2_1 = GATConv(
    8,
    attn_heads=1,
    concat_heads=True,
    dropout_rate=0.6,
    activation="elu",
    kernel_regularizer=l2(l2_reg),
    attn_kernel_regularizer=l2(l2_reg),
    bias_regularizer=l2(l2_reg),
)([x2_1, a_in_2])
x2_2 = Dropout(0.6)(x2_1)
x2_2 = GATConv(
    dataset.n_labels,
    attn_heads=1,
    concat_heads=False,
    dropout_rate=0.6,
    activation="softmax",
    kernel_regularizer=l2(l2_reg),
    attn_kernel_regularizer=l2(l2_reg),
    bias_regularizer=l2(l2_reg),
)([x2_2, a_in_2])

# Build model
model_2 = Model(inputs=[x_in_2, a_in_2], outputs=x2_2)
optimizer_2 = Adam(lr=5e-3)
loss_fn_2 = CategoricalCrossentropy()
acc_fn_2 = CategoricalAccuracy()

# %%
# @tf.function(input_signature=loader.tf_signature())
# def train_step(inputs, target):
#     with tf.GradientTape() as tape:
#         predictions = model(inputs, training=True)
#         loss = loss_fn(target, predictions) + sum(model.losses)
#     gradients = tape.gradient(loss, model.trainable_variables)
#     optimizer.apply_gradients(zip(gradients, model.trainable_variables))

# %%
# for epoch in range(100):
#     data_a2 = []
#     for batch in enumerate(loader):
#         inputs, target = batch
        
#         with tf.GradientTape() as tape:
#             predictions = model(inputs)
#             print(torch.from_numpy(target).squeeze(0).size())
#             print(list(predictions[-1].numpy()))
#             loss = loss_fn(torch.from_numpy(target).squeeze(0), predictions)
#             print(loss)
#             loss += sum(model.losses)
#         gradients = tape.gradient(loss, model.trainable_variables)
#         optimizer.apply_gradients(zip(gradients, model.trainable_variables))
#         break
#     if epoch%2==1:
#         predictions = model(inputs, training=False)
#         loss = loss_fn(torch.from_numpy(target).squeeze(0), predictions)
#         print(loss)
#     break

# %%
loader = DisjointLoader(dataset, batch_size=1,epochs=1)
for epoch in range(100):
    data_a2 = []
    data_y2 = []
    for batch in loader:
        inputs, target = batch
        with tf.GradientTape() as tape:
            predictions = model(inputs)
            #print(torch.from_numpy(target).squeeze(0).size())
            # print(predictions[-1].numpy())
            data_a2.append(list(predictions[-1].numpy()))
            data_y2.append(torch.from_numpy(target).squeeze(0)[-1].tolist())
            loss = loss_fn(torch.from_numpy(target).squeeze(0), predictions)
            loss += sum(model.losses)
        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    dataset_2 = MyDataset_2(data_a2,data_y2)
    print(dataset_2)
    loader_2 = SingleLoader(dataset_2,epochs=1)
    print(loader_2.load())
    for batch_2 in loader_2:
        inputs_2, target_2 = batch_2
        with tf.GradientTape() as tape_2:
            predictions_2 = model_2(inputs_2,training=True)
            loss_2 = loss_fn_2(torch.from_numpy(target_2).squeeze(0), predictions_2)
            loss_2 += sum(model_2.losses)
        gradients_2 = tape_2.gradient(loss_2, model_2.trainable_variables)
        optimizer_2.apply_gradients(zip(gradients_2, model_2.trainable_variables))
# Out:
# MyDataset_2(n_graphs=1)
# <RepeatDataset shapes: (((151, 151), (151, 151)), (151, 151)), types: ((tf.float32, tf.float32), tf.float32)>
# MyDataset_2(n_graphs=1)
# <RepeatDataset shapes: (((0,), (151, 151)), (0,)), types: ((tf.float32, tf.float32), tf.float32)>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-e12b3b6f419b> in <module>()
#      24         inputs_2, target_2 = batch_2
#      25         with tf.GradientTape() as tape_2:
# ---> 26             predictions_2 = model_2(inputs_2,training=True)
#      27             loss_2 = loss_fn_2(torch.from_numpy(target_2).squeeze(0), predictions_2)
#      28             loss_2 += sum(model_2.losses)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\functional.py in call(self, inputs, training, mask)
#     384     """
#     385     return self._run_internal_graph(
# --> 386         inputs, training=training, mask=mask)
#     387
#     388   def compute_output_shape(self, input_shape):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\functional.py in _run_internal_graph(self, inputs, training, mask)
#     506
#     507         args, kwargs = node.map_arguments(tensor_dict)
# --> 508         outputs = node.layer(*args, **kwargs)
#     509
#     510         # Update tensor_dict.
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# C:\we\anaconda\lib\site-packages\spektral\layers\convolutional\gat_conv.py in call(self, inputs)
#     162         x, a = inputs
#     163
# --> 164         mode = ops.autodetect_mode(x, a)
#     165         if mode == modes.SINGLE and K.is_sparse(a):
#     166             output, attn_coef = self._call_single(x, a)
#
# C:\we\anaconda\lib\site-packages\spektral\layers\ops\modes.py in autodetect_mode(x, a)
#     121         raise ValueError(
#     122             "Unknown mode for inputs x, a with ranks {} and {}"
# --> 123             "respectively.".format(x_ndim, a_ndim)
#     124         )
#
# ValueError: Unknown mode for inputs x, a with ranks 1 and 2respectively.

# %%
loader = DisjointLoader(dataset, batch_size=1,epochs=100)
loader_3 = DisjointLoader(dataset, batch_size=1,epochs=1)
for batch in loader:
    inputs, target = batch
    with tf.GradientTape() as tape:
        predictions = model(inputs)
        #print(torch.from_numpy(target).squeeze(0).size())
        # print(predictions[-1].numpy())
        loss = loss_fn(torch.from_numpy(target).squeeze(0), predictions)
        loss += sum(model.losses)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

# %%
data_a2 = []
data_y2 = []
for batch_3 in loader_3:
    inputs, target = batch_3
    predictions = model(inputs)
    data_a2.append(list(predictions[-1].numpy()))
    data_y2.append(torch.from_numpy(target).squeeze(0)[-1].tolist())

# %%
dataset_2 = MyDataset_2(data_a2,data_y2)
print(dataset_2)

loader_2 = SingleLoader(dataset_2,epochs=1000)
print(loader_2.load())
for batch_2 in loader_2:
    inputs_2, target_2 = batch_2
    with tf.GradientTape() as tape_2:
        predictions_2 = model_2(inputs_2,training=True)
        loss_2 = loss_fn_2(torch.from_numpy(target_2).squeeze(0), predictions_2)
        loss_2 += sum(model_2.losses)
    gradients_2 = tape_2.gradient(loss_2, model_2.trainable_variables)
    optimizer_2.apply_gradients(zip(gradients_2, model_2.trainable_variables))
    print(loss_2)
# Out:
# MyDataset_2(n_graphs=1)
# <RepeatDataset shapes: (((151, 151), (151, 151)), (151, 151)), types: ((tf.float32, tf.float32), tf.float32)>
# tf.Tensor(4.7835197, shape=(), dtype=float32)
# tf.Tensor(4.935944, shape=(), dtype=float32)
# tf.Tensor(4.8731656, shape=(), dtype=float32)
# tf.Tensor(4.8442597, shape=(), dtype=float32)
# tf.Tensor(4.8413787, shape=(), dtype=float32)
# tf.Tensor(5.0061474, shape=(), dtype=float32)
# tf.Tensor(4.87539, shape=(), dtype=float32)
# tf.Tensor(4.906196, shape=(), dtype=float32)
# tf.Tensor(4.8235936, shape=(), dtype=float32)
# tf.Tensor(4.794607, shape=(), dtype=float32)
# tf.Tensor(4.8746176, shape=(), dtype=float32)
# tf.Tensor(4.777262, shape=(), dtype=float32)
# tf.Tensor(4.922296, shape=(), dtype=float32)
# tf.Tensor(4.915993, shape=(), dtype=float32)
# tf.Tensor(4.7875113, shape=(), dtype=float32)
# tf.Tensor(4.8926888, shape=(), dtype=float32)
# tf.Tensor(4.764992, shape=(), dtype=float32)
# tf.Tensor(4.918975, shape=(), dtype=float32)
# tf.Tensor(4.8604474, shape=(), dtype=float32)
# tf.Tensor(4.7345834, shape=(), dtype=float32)
# tf.Tensor(4.946789, shape=(), dtype=float32)
# tf.Tensor(4.781452, shape=(), dtype=float32)
# tf.Tensor(4.856962, shape=(), dtype=float32)
# tf.Tensor(4.9839478, shape=(), dtype=float32)
# tf.Tensor(4.7462606, shape=(), dtype=float32)
# tf.Tensor(4.8529696, shape=(), dtype=float32)
# tf.Tensor(4.9028883, shape=(), dtype=float32)
# tf.Tensor(4.9149475, shape=(), dtype=float32)
# tf.Tensor(4.843256, shape=(), dtype=float32)
# tf.Tensor(4.897695, shape=(), dtype=float32)
# tf.Tensor(4.897615, shape=(), dtype=float32)
# tf.Tensor(4.887158, shape=(), dtype=float32)
# tf.Tensor(4.8813863, shape=(), dtype=float32)
# tf.Tensor(4.8836393, shape=(), dtype=float32)
# tf.Tensor(4.818056, shape=(), dtype=float32)
# tf.Tensor(4.916223, shape=(), dtype=float32)
# tf.Tensor(4.898989, shape=(), dtype=float32)
# tf.Tensor(4.7706428, shape=(), dtype=float32)
# tf.Tensor(4.835344, shape=(), dtype=float32)
# tf.Tensor(4.8380084, shape=(), dtype=float32)
# tf.Tensor(4.948752, shape=(), dtype=float32)
# tf.Tensor(4.963754, shape=(), dtype=float32)
# tf.Tensor(4.7186193, shape=(), dtype=float32)
# tf.Tensor(4.78775, shape=(), dtype=float32)
# tf.Tensor(4.95322, shape=(), dtype=float32)
# tf.Tensor(4.8726583, shape=(), dtype=float32)
# tf.Tensor(4.895338, shape=(), dtype=float32)
# tf.Tensor(4.8803387, shape=(), dtype=float32)
# tf.Tensor(4.8873014, shape=(), dtype=float32)
# tf.Tensor(4.9159646, shape=(), dtype=float32)
# tf.Tensor(4.887437, shape=(), dtype=float32)
# tf.Tensor(4.955978, shape=(), dtype=float32)
# tf.Tensor(4.9508524, shape=(), dtype=float32)
# tf.Tensor(4.887767, shape=(), dtype=float32)
# tf.Tensor(4.8944526, shape=(), dtype=float32)
# tf.Tensor(4.874495, shape=(), dtype=float32)
# tf.Tensor(4.8532634, shape=(), dtype=float32)
# tf.Tensor(4.800574, shape=(), dtype=float32)
# tf.Tensor(4.957607, shape=(), dtype=float32)
# tf.Tensor(4.7975554, shape=(), dtype=float32)
# tf.Tensor(4.8471513, shape=(), dtype=float32)
# tf.Tensor(4.854192, shape=(), dtype=float32)
# tf.Tensor(4.8881316, shape=(), dtype=float32)
# tf.Tensor(4.9507775, shape=(), dtype=float32)
# tf.Tensor(4.914434, shape=(), dtype=float32)
# tf.Tensor(4.9161544, shape=(), dtype=float32)
# tf.Tensor(4.8671613, shape=(), dtype=float32)
# tf.Tensor(4.87328, shape=(), dtype=float32)
# tf.Tensor(4.8693132, shape=(), dtype=float32)
# tf.Tensor(4.8872976, shape=(), dtype=float32)
# tf.Tensor(5.0286627, shape=(), dtype=float32)
# tf.Tensor(5.005335, shape=(), dtype=float32)
# tf.Tensor(4.793535, shape=(), dtype=float32)
# tf.Tensor(4.88495, shape=(), dtype=float32)
# tf.Tensor(4.9238396, shape=(), dtype=float32)
# tf.Tensor(4.926416, shape=(), dtype=float32)
# tf.Tensor(4.8071733, shape=(), dtype=float32)
# tf.Tensor(4.736786, shape=(), dtype=float32)
# tf.Tensor(4.916574, shape=(), dtype=float32)
# tf.Tensor(4.8521132, shape=(), dtype=float32)
# tf.Tensor(4.9123955, shape=(), dtype=float32)
# tf.Tensor(4.7463384, shape=(), dtype=float32)
# tf.Tensor(4.8266234, shape=(), dtype=float32)
# tf.Tensor(4.918235, shape=(), dtype=float32)
# tf.Tensor(4.9160414, shape=(), dtype=float32)
# tf.Tensor(4.840832, shape=(), dtype=float32)
# tf.Tensor(4.8935227, shape=(), dtype=float32)
# tf.Tensor(4.848922, shape=(), dtype=float32)
# tf.Tensor(4.8525524, shape=(), dtype=float32)
# tf.Tensor(4.752079, shape=(), dtype=float32)
# tf.Tensor(4.8956394, shape=(), dtype=float32)
# tf.Tensor(4.9368286, shape=(), dtype=float32)
# tf.Tensor(4.907311, shape=(), dtype=float32)
# tf.Tensor(4.893445, shape=(), dtype=float32)
# tf.Tensor(4.7884474, shape=(), dtype=float32)
# tf.Tensor(4.825746, shape=(), dtype=float32)
# tf.Tensor(4.945156, shape=(), dtype=float32)
# tf.Tensor(4.950521, shape=(), dtype=float32)
# tf.Tensor(4.7948384, shape=(), dtype=float32)
# tf.Tensor(4.8892336, shape=(), dtype=float32)
# tf.Tensor(4.8993115, shape=(), dtype=float32)
# tf.Tensor(4.929903, shape=(), dtype=float32)
# tf.Tensor(4.903238, shape=(), dtype=float32)
# tf.Tensor(4.925621, shape=(), dtype=float32)
# tf.Tensor(4.8122196, shape=(), dtype=float32)
# tf.Tensor(4.8310866, shape=(), dtype=float32)
# tf.Tensor(5.0096116, shape=(), dtype=float32)
# tf.Tensor(4.7350674, shape=(), dtype=float32)
# tf.Tensor(4.841118, shape=(), dtype=float32)
# tf.Tensor(4.8396015, shape=(), dtype=float32)
# tf.Tensor(4.811327, shape=(), dtype=float32)
# tf.Tensor(4.8376613, shape=(), dtype=float32)
# tf.Tensor(4.8136587, shape=(), dtype=float32)
# tf.Tensor(4.8532257, shape=(), dtype=float32)
# tf.Tensor(5.0032268, shape=(), dtype=float32)
# tf.Tensor(4.8470163, shape=(), dtype=float32)
# tf.Tensor(4.9122024, shape=(), dtype=float32)
# tf.Tensor(4.869191, shape=(), dtype=float32)
# tf.Tensor(4.87183, shape=(), dtype=float32)
# tf.Tensor(4.9366727, shape=(), dtype=float32)
# tf.Tensor(4.9125338, shape=(), dtype=float32)
# tf.Tensor(4.849953, shape=(), dtype=float32)
# tf.Tensor(4.9951043, shape=(), dtype=float32)
# tf.Tensor(4.819284, shape=(), dtype=float32)
# tf.Tensor(4.843973, shape=(), dtype=float32)
# tf.Tensor(4.910524, shape=(), dtype=float32)
# tf.Tensor(4.843935, shape=(), dtype=float32)
# tf.Tensor(4.820532, shape=(), dtype=float32)
# tf.Tensor(4.8109813, shape=(), dtype=float32)
# tf.Tensor(4.7719707, shape=(), dtype=float32)
# tf.Tensor(4.809526, shape=(), dtype=float32)
# tf.Tensor(4.8739166, shape=(), dtype=float32)
# tf.Tensor(4.888572, shape=(), dtype=float32)
# tf.Tensor(4.8185134, shape=(), dtype=float32)
# tf.Tensor(4.8684464, shape=(), dtype=float32)
# tf.Tensor(5.0008197, shape=(), dtype=float32)
# tf.Tensor(4.864706, shape=(), dtype=float32)
# tf.Tensor(4.95049, shape=(), dtype=float32)
# tf.Tensor(4.7174745, shape=(), dtype=float32)
# tf.Tensor(4.9064183, shape=(), dtype=float32)
# tf.Tensor(4.836141, shape=(), dtype=float32)
# tf.Tensor(4.637878, shape=(), dtype=float32)
# tf.Tensor(4.7082534, shape=(), dtype=float32)
# tf.Tensor(4.91048, shape=(), dtype=float32)
# tf.Tensor(4.7744937, shape=(), dtype=float32)
# tf.Tensor(4.7768183, shape=(), dtype=float32)
# tf.Tensor(4.7971935, shape=(), dtype=float32)
# tf.Tensor(4.8228345, shape=(), dtype=float32)
# tf.Tensor(4.8624945, shape=(), dtype=float32)
# tf.Tensor(4.9947195, shape=(), dtype=float32)
# tf.Tensor(4.8781457, shape=(), dtype=float32)
# tf.Tensor(4.7109127, shape=(), dtype=float32)
# tf.Tensor(4.891309, shape=(), dtype=float32)
# tf.Tensor(4.866582, shape=(), dtype=float32)
# tf.Tensor(4.7434807, shape=(), dtype=float32)
# tf.Tensor(4.8799744, shape=(), dtype=float32)
# tf.Tensor(4.8114877, shape=(), dtype=float32)
# tf.Tensor(4.686505, shape=(), dtype=float32)
# tf.Tensor(4.882969, shape=(), dtype=float32)
# tf.Tensor(4.926044, shape=(), dtype=float32)
# tf.Tensor(4.9136086, shape=(), dtype=float32)
# tf.Tensor(4.7267156, shape=(), dtype=float32)
# tf.Tensor(4.7224727, shape=(), dtype=float32)
# tf.Tensor(4.80707, shape=(), dtype=float32)
# tf.Tensor(4.8237615, shape=(), dtype=float32)
# tf.Tensor(4.926763, shape=(), dtype=float32)
# tf.Tensor(4.847162, shape=(), dtype=float32)
# tf.Tensor(4.951201, shape=(), dtype=float32)
# tf.Tensor(4.973526, shape=(), dtype=float32)
# tf.Tensor(4.7373223, shape=(), dtype=float32)
# tf.Tensor(4.9379325, shape=(), dtype=float32)
# tf.Tensor(4.704003, shape=(), dtype=float32)
# tf.Tensor(4.832117, shape=(), dtype=float32)
# tf.Tensor(4.861122, shape=(), dtype=float32)
# tf.Tensor(4.827415, shape=(), dtype=float32)
# tf.Tensor(4.7432427, shape=(), dtype=float32)
# tf.Tensor(4.8901143, shape=(), dtype=float32)
# tf.Tensor(4.9010653, shape=(), dtype=float32)
# tf.Tensor(4.968304, shape=(), dtype=float32)
# tf.Tensor(4.8666735, shape=(), dtype=float32)
# tf.Tensor(4.9378595, shape=(), dtype=float32)
# tf.Tensor(4.86858, shape=(), dtype=float32)
# tf.Tensor(4.896116, shape=(), dtype=float32)
# tf.Tensor(4.8953857, shape=(), dtype=float32)
# tf.Tensor(4.9059615, shape=(), dtype=float32)
# tf.Tensor(4.7933574, shape=(), dtype=float32)
# tf.Tensor(4.8727136, shape=(), dtype=float32)
# tf.Tensor(4.8315115, shape=(), dtype=float32)
# tf.Tensor(4.827498, shape=(), dtype=float32)
# tf.Tensor(4.997588, shape=(), dtype=float32)
# tf.Tensor(4.8900676, shape=(), dtype=float32)
# tf.Tensor(4.857282, shape=(), dtype=float32)
# tf.Tensor(4.832359, shape=(), dtype=float32)
# tf.Tensor(4.904085, shape=(), dtype=float32)
# tf.Tensor(4.852811, shape=(), dtype=float32)
# tf.Tensor(4.8152037, shape=(), dtype=float32)
# tf.Tensor(4.901704, shape=(), dtype=float32)
# tf.Tensor(4.95186, shape=(), dtype=float32)
# tf.Tensor(4.857441, shape=(), dtype=float32)
# tf.Tensor(4.881283, shape=(), dtype=float32)
# tf.Tensor(4.801626, shape=(), dtype=float32)
# tf.Tensor(4.9276977, shape=(), dtype=float32)
# tf.Tensor(4.85477, shape=(), dtype=float32)
# tf.Tensor(4.852595, shape=(), dtype=float32)
# tf.Tensor(4.917266, shape=(), dtype=float32)
# tf.Tensor(4.7395697, shape=(), dtype=float32)
# tf.Tensor(4.8462014, shape=(), dtype=float32)
# tf.Tensor(4.860948, shape=(), dtype=float32)
# tf.Tensor(4.9229927, shape=(), dtype=float32)
# tf.Tensor(4.915339, shape=(), dtype=float32)
# tf.Tensor(4.8883743, shape=(), dtype=float32)
# tf.Tensor(4.740678, shape=(), dtype=float32)
# tf.Tensor(4.8912005, shape=(), dtype=float32)
# tf.Tensor(4.7909417, shape=(), dtype=float32)
# tf.Tensor(4.80038, shape=(), dtype=float32)
# tf.Tensor(4.9355974, shape=(), dtype=float32)
# tf.Tensor(4.8230424, shape=(), dtype=float32)
# tf.Tensor(4.8404555, shape=(), dtype=float32)
# tf.Tensor(4.785178, shape=(), dtype=float32)
# tf.Tensor(4.7231092, shape=(), dtype=float32)
# tf.Tensor(4.863922, shape=(), dtype=float32)
# tf.Tensor(4.8257837, shape=(), dtype=float32)
# tf.Tensor(4.6835, shape=(), dtype=float32)
# tf.Tensor(4.6721663, shape=(), dtype=float32)
# tf.Tensor(4.8949614, shape=(), dtype=float32)
# tf.Tensor(4.90491, shape=(), dtype=float32)
# tf.Tensor(4.8588815, shape=(), dtype=float32)
# tf.Tensor(4.6641827, shape=(), dtype=float32)
# tf.Tensor(4.757232, shape=(), dtype=float32)
# tf.Tensor(4.8296056, shape=(), dtype=float32)
# tf.Tensor(4.8803706, shape=(), dtype=float32)
# tf.Tensor(4.856881, shape=(), dtype=float32)
# tf.Tensor(4.732746, shape=(), dtype=float32)
# tf.Tensor(4.862382, shape=(), dtype=float32)
# tf.Tensor(4.8468795, shape=(), dtype=float32)
# tf.Tensor(4.6927514, shape=(), dtype=float32)
# tf.Tensor(4.900662, shape=(), dtype=float32)
# tf.Tensor(4.8196545, shape=(), dtype=float32)
# tf.Tensor(4.9346137, shape=(), dtype=float32)
# tf.Tensor(4.899369, shape=(), dtype=float32)
# tf.Tensor(4.9455585, shape=(), dtype=float32)
# tf.Tensor(4.7788653, shape=(), dtype=float32)
# tf.Tensor(4.877656, shape=(), dtype=float32)
# tf.Tensor(4.8656387, shape=(), dtype=float32)
# tf.Tensor(4.8278313, shape=(), dtype=float32)
# tf.Tensor(4.9400153, shape=(), dtype=float32)
# tf.Tensor(4.9224744, shape=(), dtype=float32)
# tf.Tensor(4.8843145, shape=(), dtype=float32)
# tf.Tensor(4.829508, shape=(), dtype=float32)
# tf.Tensor(4.7220225, shape=(), dtype=float32)
# tf.Tensor(4.6995597, shape=(), dtype=float32)
# tf.Tensor(4.960816, shape=(), dtype=float32)
# tf.Tensor(4.8771195, shape=(), dtype=float32)
# tf.Tensor(4.9356904, shape=(), dtype=float32)
# tf.Tensor(4.7928967, shape=(), dtype=float32)
# tf.Tensor(4.8385444, shape=(), dtype=float32)
# tf.Tensor(4.920874, shape=(), dtype=float32)
# tf.Tensor(4.944376, shape=(), dtype=float32)
# tf.Tensor(4.845205, shape=(), dtype=float32)
# tf.Tensor(4.7883124, shape=(), dtype=float32)
# tf.Tensor(4.803843, shape=(), dtype=float32)
# tf.Tensor(4.8390865, shape=(), dtype=float32)
# tf.Tensor(4.8015428, shape=(), dtype=float32)
# tf.Tensor(4.883752, shape=(), dtype=float32)
# tf.Tensor(4.8764577, shape=(), dtype=float32)
# tf.Tensor(4.753854, shape=(), dtype=float32)
# tf.Tensor(4.7604446, shape=(), dtype=float32)
# tf.Tensor(4.8974557, shape=(), dtype=float32)
# tf.Tensor(4.8016596, shape=(), dtype=float32)
# tf.Tensor(4.9254265, shape=(), dtype=float32)
# tf.Tensor(4.9067974, shape=(), dtype=float32)
# tf.Tensor(5.021343, shape=(), dtype=float32)
# tf.Tensor(4.935532, shape=(), dtype=float32)
# tf.Tensor(4.904697, shape=(), dtype=float32)
# tf.Tensor(4.929627, shape=(), dtype=float32)
# tf.Tensor(4.791959, shape=(), dtype=float32)
# tf.Tensor(4.766856, shape=(), dtype=float32)
# tf.Tensor(4.7554097, shape=(), dtype=float32)
# tf.Tensor(4.9504395, shape=(), dtype=float32)
# tf.Tensor(4.985705, shape=(), dtype=float32)
# tf.Tensor(4.898178, shape=(), dtype=float32)
# tf.Tensor(4.871421, shape=(), dtype=float32)
# tf.Tensor(4.9578114, shape=(), dtype=float32)
# tf.Tensor(4.875852, shape=(), dtype=float32)
# tf.Tensor(4.8775206, shape=(), dtype=float32)
# tf.Tensor(4.7685003, shape=(), dtype=float32)
# tf.Tensor(4.854152, shape=(), dtype=float32)
# tf.Tensor(4.939362, shape=(), dtype=float32)
# tf.Tensor(4.767012, shape=(), dtype=float32)
# tf.Tensor(4.944067, shape=(), dtype=float32)
# tf.Tensor(4.8580213, shape=(), dtype=float32)
# tf.Tensor(4.8407745, shape=(), dtype=float32)
# tf.Tensor(4.762995, shape=(), dtype=float32)
# tf.Tensor(4.849405, shape=(), dtype=float32)
# tf.Tensor(4.8195963, shape=(), dtype=float32)
# tf.Tensor(4.767987, shape=(), dtype=float32)
# tf.Tensor(4.8638077, shape=(), dtype=float32)
# tf.Tensor(4.9666004, shape=(), dtype=float32)
# tf.Tensor(4.884836, shape=(), dtype=float32)
# tf.Tensor(4.9314294, shape=(), dtype=float32)
# tf.Tensor(4.9146175, shape=(), dtype=float32)
# tf.Tensor(4.7150035, shape=(), dtype=float32)
# tf.Tensor(4.8150597, shape=(), dtype=float32)
# tf.Tensor(4.8644795, shape=(), dtype=float32)
# tf.Tensor(4.9110603, shape=(), dtype=float32)
# tf.Tensor(4.9583254, shape=(), dtype=float32)
# tf.Tensor(4.820811, shape=(), dtype=float32)
# tf.Tensor(4.88103, shape=(), dtype=float32)
# tf.Tensor(4.8704686, shape=(), dtype=float32)
# tf.Tensor(4.9480276, shape=(), dtype=float32)
# tf.Tensor(4.784504, shape=(), dtype=float32)
# tf.Tensor(4.784463, shape=(), dtype=float32)
# tf.Tensor(4.73631, shape=(), dtype=float32)
# tf.Tensor(4.8648615, shape=(), dtype=float32)
# tf.Tensor(4.8118253, shape=(), dtype=float32)
# tf.Tensor(4.7376876, shape=(), dtype=float32)
# tf.Tensor(4.849669, shape=(), dtype=float32)
# tf.Tensor(4.8995624, shape=(), dtype=float32)
# tf.Tensor(4.911957, shape=(), dtype=float32)
# tf.Tensor(4.9048486, shape=(), dtype=float32)
# tf.Tensor(4.9981923, shape=(), dtype=float32)
# tf.Tensor(4.8593764, shape=(), dtype=float32)
# tf.Tensor(4.725846, shape=(), dtype=float32)
# tf.Tensor(4.8819256, shape=(), dtype=float32)
# tf.Tensor(4.777292, shape=(), dtype=float32)
# tf.Tensor(4.8226857, shape=(), dtype=float32)
# tf.Tensor(4.8079324, shape=(), dtype=float32)
# tf.Tensor(4.9257126, shape=(), dtype=float32)
# tf.Tensor(4.9445944, shape=(), dtype=float32)
# tf.Tensor(4.922696, shape=(), dtype=float32)
# tf.Tensor(4.7555547, shape=(), dtype=float32)
# tf.Tensor(4.8224497, shape=(), dtype=float32)
# tf.Tensor(4.7460995, shape=(), dtype=float32)
# tf.Tensor(4.854829, shape=(), dtype=float32)
# tf.Tensor(4.9189816, shape=(), dtype=float32)
# tf.Tensor(4.95015, shape=(), dtype=float32)
# tf.Tensor(4.8756766, shape=(), dtype=float32)
# tf.Tensor(4.8084116, shape=(), dtype=float32)
# tf.Tensor(4.8743234, shape=(), dtype=float32)
# tf.Tensor(4.7862024, shape=(), dtype=float32)
# tf.Tensor(4.954663, shape=(), dtype=float32)
# tf.Tensor(4.906501, shape=(), dtype=float32)
# tf.Tensor(4.8755918, shape=(), dtype=float32)
# tf.Tensor(4.793114, shape=(), dtype=float32)
# tf.Tensor(4.808712, shape=(), dtype=float32)
# tf.Tensor(4.984569, shape=(), dtype=float32)
# tf.Tensor(4.861115, shape=(), dtype=float32)
# tf.Tensor(4.86581, shape=(), dtype=float32)
# tf.Tensor(4.84251, shape=(), dtype=float32)
# tf.Tensor(4.932064, shape=(), dtype=float32)
# tf.Tensor(4.7477374, shape=(), dtype=float32)
# tf.Tensor(4.9254785, shape=(), dtype=float32)
# tf.Tensor(4.83446, shape=(), dtype=float32)
# tf.Tensor(4.8551555, shape=(), dtype=float32)
# tf.Tensor(4.951792, shape=(), dtype=float32)
# tf.Tensor(4.91215, shape=(), dtype=float32)
# tf.Tensor(4.8626957, shape=(), dtype=float32)
# tf.Tensor(4.875146, shape=(), dtype=float32)
# tf.Tensor(4.9599123, shape=(), dtype=float32)
# tf.Tensor(4.7935963, shape=(), dtype=float32)
# tf.Tensor(4.8462954, shape=(), dtype=float32)
# tf.Tensor(4.9455657, shape=(), dtype=float32)
# tf.Tensor(4.8374753, shape=(), dtype=float32)
# tf.Tensor(4.810832, shape=(), dtype=float32)
# tf.Tensor(4.902793, shape=(), dtype=float32)
# tf.Tensor(4.945718, shape=(), dtype=float32)
# tf.Tensor(4.865675, shape=(), dtype=float32)
# tf.Tensor(4.836469, shape=(), dtype=float32)
# tf.Tensor(4.929747, shape=(), dtype=float32)
# tf.Tensor(4.867347, shape=(), dtype=float32)
# tf.Tensor(4.8001566, shape=(), dtype=float32)
# tf.Tensor(4.7955136, shape=(), dtype=float32)
# tf.Tensor(4.8464236, shape=(), dtype=float32)
# tf.Tensor(4.8274975, shape=(), dtype=float32)
# tf.Tensor(4.8173947, shape=(), dtype=float32)
# tf.Tensor(4.850119, shape=(), dtype=float32)
# tf.Tensor(4.912563, shape=(), dtype=float32)
# tf.Tensor(5.0298624, shape=(), dtype=float32)
# tf.Tensor(4.846555, shape=(), dtype=float32)
# tf.Tensor(4.831498, shape=(), dtype=float32)
# tf.Tensor(4.951376, shape=(), dtype=float32)
# tf.Tensor(4.8249803, shape=(), dtype=float32)
# tf.Tensor(4.9155893, shape=(), dtype=float32)
# tf.Tensor(4.848966, shape=(), dtype=float32)
# tf.Tensor(4.7931333, shape=(), dtype=float32)
# tf.Tensor(4.8659434, shape=(), dtype=float32)
# tf.Tensor(4.9391985, shape=(), dtype=float32)
# tf.Tensor(4.8244843, shape=(), dtype=float32)
# tf.Tensor(4.7908854, shape=(), dtype=float32)
# tf.Tensor(4.881329, shape=(), dtype=float32)
# tf.Tensor(4.67763, shape=(), dtype=float32)
# tf.Tensor(4.781547, shape=(), dtype=float32)
# tf.Tensor(4.890482, shape=(), dtype=float32)
# tf.Tensor(4.860674, shape=(), dtype=float32)
# tf.Tensor(4.712252, shape=(), dtype=float32)
# tf.Tensor(5.011743, shape=(), dtype=float32)
# tf.Tensor(4.844293, shape=(), dtype=float32)
# tf.Tensor(4.868479, shape=(), dtype=float32)
# tf.Tensor(4.827437, shape=(), dtype=float32)
# tf.Tensor(4.8330197, shape=(), dtype=float32)
# tf.Tensor(4.845769, shape=(), dtype=float32)
# tf.Tensor(5.0282593, shape=(), dtype=float32)
# tf.Tensor(4.7483964, shape=(), dtype=float32)
# tf.Tensor(4.923207, shape=(), dtype=float32)
# tf.Tensor(4.980525, shape=(), dtype=float32)
# tf.Tensor(4.7537136, shape=(), dtype=float32)
# tf.Tensor(4.907619, shape=(), dtype=float32)
# tf.Tensor(4.9299664, shape=(), dtype=float32)
# tf.Tensor(4.871667, shape=(), dtype=float32)
# tf.Tensor(4.988472, shape=(), dtype=float32)
# tf.Tensor(4.8969088, shape=(), dtype=float32)
# tf.Tensor(4.693904, shape=(), dtype=float32)
# tf.Tensor(4.7764635, shape=(), dtype=float32)
# tf.Tensor(4.775571, shape=(), dtype=float32)
# tf.Tensor(4.7283397, shape=(), dtype=float32)
# tf.Tensor(4.8850546, shape=(), dtype=float32)
# tf.Tensor(4.8727975, shape=(), dtype=float32)
# tf.Tensor(4.8502355, shape=(), dtype=float32)
# tf.Tensor(4.8069177, shape=(), dtype=float32)
# tf.Tensor(4.810664, shape=(), dtype=float32)
# tf.Tensor(4.8647056, shape=(), dtype=float32)
# tf.Tensor(4.91648, shape=(), dtype=float32)
# tf.Tensor(4.847476, shape=(), dtype=float32)
# tf.Tensor(4.823992, shape=(), dtype=float32)
# tf.Tensor(4.8456206, shape=(), dtype=float32)
# tf.Tensor(4.763215, shape=(), dtype=float32)
# tf.Tensor(4.9291563, shape=(), dtype=float32)
# tf.Tensor(4.8648167, shape=(), dtype=float32)
# tf.Tensor(4.837424, shape=(), dtype=float32)
# tf.Tensor(4.7009516, shape=(), dtype=float32)
# tf.Tensor(4.9288135, shape=(), dtype=float32)
# tf.Tensor(4.9502254, shape=(), dtype=float32)
# tf.Tensor(4.802426, shape=(), dtype=float32)
# tf.Tensor(4.7472, shape=(), dtype=float32)
# tf.Tensor(4.8322473, shape=(), dtype=float32)
# tf.Tensor(4.873734, shape=(), dtype=float32)
# tf.Tensor(4.830497, shape=(), dtype=float32)
# tf.Tensor(4.876196, shape=(), dtype=float32)
# tf.Tensor(4.7478137, shape=(), dtype=float32)
# tf.Tensor(4.9218535, shape=(), dtype=float32)
# tf.Tensor(4.853649, shape=(), dtype=float32)
# tf.Tensor(4.8045416, shape=(), dtype=float32)
# tf.Tensor(4.820563, shape=(), dtype=float32)
# tf.Tensor(4.850154, shape=(), dtype=float32)
# tf.Tensor(4.810177, shape=(), dtype=float32)
# tf.Tensor(4.884555, shape=(), dtype=float32)
# tf.Tensor(4.8060226, shape=(), dtype=float32)
# tf.Tensor(4.884859, shape=(), dtype=float32)
# tf.Tensor(4.887706, shape=(), dtype=float32)
# tf.Tensor(4.878943, shape=(), dtype=float32)
# tf.Tensor(4.865106, shape=(), dtype=float32)
# tf.Tensor(4.8710346, shape=(), dtype=float32)
# tf.Tensor(4.936964, shape=(), dtype=float32)
# tf.Tensor(4.8476095, shape=(), dtype=float32)
# tf.Tensor(4.8934593, shape=(), dtype=float32)
# tf.Tensor(4.7976403, shape=(), dtype=float32)
# tf.Tensor(4.9909024, shape=(), dtype=float32)
# tf.Tensor(4.907118, shape=(), dtype=float32)
# tf.Tensor(4.8183765, shape=(), dtype=float32)
# tf.Tensor(4.9137254, shape=(), dtype=float32)
# tf.Tensor(4.851628, shape=(), dtype=float32)
# tf.Tensor(4.8026056, shape=(), dtype=float32)
# tf.Tensor(4.877846, shape=(), dtype=float32)
# tf.Tensor(4.87, shape=(), dtype=float32)
# tf.Tensor(4.6445403, shape=(), dtype=float32)
# tf.Tensor(4.868825, shape=(), dtype=float32)
# tf.Tensor(4.8025947, shape=(), dtype=float32)
# tf.Tensor(4.8959074, shape=(), dtype=float32)
# tf.Tensor(4.865606, shape=(), dtype=float32)
# tf.Tensor(4.7656536, shape=(), dtype=float32)
# tf.Tensor(4.7985644, shape=(), dtype=float32)
# tf.Tensor(4.8465366, shape=(), dtype=float32)
# tf.Tensor(4.845278, shape=(), dtype=float32)
# tf.Tensor(4.9008765, shape=(), dtype=float32)
# tf.Tensor(4.9710426, shape=(), dtype=float32)
# tf.Tensor(4.760123, shape=(), dtype=float32)
# tf.Tensor(4.9252687, shape=(), dtype=float32)
# tf.Tensor(4.8603253, shape=(), dtype=float32)
# tf.Tensor(4.8848467, shape=(), dtype=float32)
# tf.Tensor(4.8361335, shape=(), dtype=float32)
# tf.Tensor(4.772555, shape=(), dtype=float32)
# tf.Tensor(4.9432836, shape=(), dtype=float32)
# tf.Tensor(4.6632347, shape=(), dtype=float32)
# tf.Tensor(4.8030033, shape=(), dtype=float32)
# tf.Tensor(4.7846065, shape=(), dtype=float32)
# tf.Tensor(4.7516766, shape=(), dtype=float32)
# tf.Tensor(4.8197346, shape=(), dtype=float32)
# tf.Tensor(4.769778, shape=(), dtype=float32)
# tf.Tensor(4.8834014, shape=(), dtype=float32)
# tf.Tensor(4.791563, shape=(), dtype=float32)
# tf.Tensor(4.7588573, shape=(), dtype=float32)
# tf.Tensor(4.766025, shape=(), dtype=float32)
# tf.Tensor(4.891869, shape=(), dtype=float32)
# tf.Tensor(4.7894726, shape=(), dtype=float32)
# tf.Tensor(4.8552885, shape=(), dtype=float32)
# tf.Tensor(4.8665605, shape=(), dtype=float32)
# tf.Tensor(4.8879876, shape=(), dtype=float32)
# tf.Tensor(4.87487, shape=(), dtype=float32)
# tf.Tensor(4.798284, shape=(), dtype=float32)
# tf.Tensor(4.8986235, shape=(), dtype=float32)
# tf.Tensor(4.9946303, shape=(), dtype=float32)
# tf.Tensor(4.9920206, shape=(), dtype=float32)
# tf.Tensor(4.920878, shape=(), dtype=float32)
# tf.Tensor(4.8774652, shape=(), dtype=float32)
# tf.Tensor(4.911414, shape=(), dtype=float32)
# tf.Tensor(4.811921, shape=(), dtype=float32)
# tf.Tensor(4.9591317, shape=(), dtype=float32)
# tf.Tensor(4.813556, shape=(), dtype=float32)
# tf.Tensor(4.8176003, shape=(), dtype=float32)
# tf.Tensor(4.6759124, shape=(), dtype=float32)
# tf.Tensor(4.887651, shape=(), dtype=float32)
# tf.Tensor(4.8011327, shape=(), dtype=float32)
# tf.Tensor(4.899385, shape=(), dtype=float32)
# tf.Tensor(4.799978, shape=(), dtype=float32)
# tf.Tensor(4.93024, shape=(), dtype=float32)
# tf.Tensor(4.85036, shape=(), dtype=float32)
# tf.Tensor(4.6318345, shape=(), dtype=float32)
# tf.Tensor(4.891987, shape=(), dtype=float32)
# tf.Tensor(4.7499676, shape=(), dtype=float32)
# tf.Tensor(4.824739, shape=(), dtype=float32)
# tf.Tensor(4.897442, shape=(), dtype=float32)
# tf.Tensor(4.9870057, shape=(), dtype=float32)
# tf.Tensor(4.827969, shape=(), dtype=float32)
# tf.Tensor(4.844563, shape=(), dtype=float32)
# tf.Tensor(4.909029, shape=(), dtype=float32)
# tf.Tensor(4.806439, shape=(), dtype=float32)
# tf.Tensor(4.825519, shape=(), dtype=float32)
# tf.Tensor(4.9166393, shape=(), dtype=float32)
# tf.Tensor(4.8771048, shape=(), dtype=float32)
# tf.Tensor(4.9650464, shape=(), dtype=float32)
# tf.Tensor(4.691649, shape=(), dtype=float32)
# tf.Tensor(4.8464503, shape=(), dtype=float32)
# tf.Tensor(4.9437494, shape=(), dtype=float32)
# tf.Tensor(4.8889, shape=(), dtype=float32)
# tf.Tensor(4.888501, shape=(), dtype=float32)
# tf.Tensor(4.8153105, shape=(), dtype=float32)
# tf.Tensor(4.864531, shape=(), dtype=float32)
# tf.Tensor(4.762131, shape=(), dtype=float32)
# tf.Tensor(4.7701097, shape=(), dtype=float32)
# tf.Tensor(4.9512944, shape=(), dtype=float32)
# tf.Tensor(4.81382, shape=(), dtype=float32)
# tf.Tensor(4.9692855, shape=(), dtype=float32)
# tf.Tensor(4.6908355, shape=(), dtype=float32)
# tf.Tensor(4.7910714, shape=(), dtype=float32)
# tf.Tensor(4.905154, shape=(), dtype=float32)
# tf.Tensor(4.820795, shape=(), dtype=float32)
# tf.Tensor(4.9347353, shape=(), dtype=float32)
# tf.Tensor(4.8512473, shape=(), dtype=float32)
# tf.Tensor(4.7019534, shape=(), dtype=float32)
# tf.Tensor(4.7198687, shape=(), dtype=float32)
# tf.Tensor(4.8799, shape=(), dtype=float32)
# tf.Tensor(4.9311876, shape=(), dtype=float32)
# tf.Tensor(4.9005895, shape=(), dtype=float32)
# tf.Tensor(4.8180733, shape=(), dtype=float32)
# tf.Tensor(4.8464804, shape=(), dtype=float32)
# tf.Tensor(4.857806, shape=(), dtype=float32)
# tf.Tensor(4.7504277, shape=(), dtype=float32)
# tf.Tensor(4.9063616, shape=(), dtype=float32)
# tf.Tensor(4.7979712, shape=(), dtype=float32)
# tf.Tensor(4.845623, shape=(), dtype=float32)
# tf.Tensor(4.7139215, shape=(), dtype=float32)
# tf.Tensor(4.836914, shape=(), dtype=float32)
# tf.Tensor(4.8503103, shape=(), dtype=float32)
# tf.Tensor(4.914771, shape=(), dtype=float32)
# tf.Tensor(4.935631, shape=(), dtype=float32)
# tf.Tensor(4.8197875, shape=(), dtype=float32)
# tf.Tensor(4.8599143, shape=(), dtype=float32)
# tf.Tensor(4.884829, shape=(), dtype=float32)
# tf.Tensor(4.871535, shape=(), dtype=float32)
# tf.Tensor(4.876861, shape=(), dtype=float32)
# tf.Tensor(4.8331766, shape=(), dtype=float32)
# tf.Tensor(4.8773108, shape=(), dtype=float32)
# tf.Tensor(4.8968086, shape=(), dtype=float32)
# tf.Tensor(4.816821, shape=(), dtype=float32)
# tf.Tensor(4.7896795, shape=(), dtype=float32)
# tf.Tensor(4.845116, shape=(), dtype=float32)
# tf.Tensor(4.918213, shape=(), dtype=float32)
# tf.Tensor(4.928085, shape=(), dtype=float32)
# tf.Tensor(4.836951, shape=(), dtype=float32)
# tf.Tensor(4.862548, shape=(), dtype=float32)
# tf.Tensor(4.8299255, shape=(), dtype=float32)
# tf.Tensor(4.8242445, shape=(), dtype=float32)
# tf.Tensor(4.8623633, shape=(), dtype=float32)
# tf.Tensor(4.6360655, shape=(), dtype=float32)
# tf.Tensor(4.903963, shape=(), dtype=float32)
# tf.Tensor(4.8681965, shape=(), dtype=float32)
# tf.Tensor(4.7585416, shape=(), dtype=float32)
# tf.Tensor(4.848529, shape=(), dtype=float32)
# tf.Tensor(4.7808414, shape=(), dtype=float32)
# tf.Tensor(4.839821, shape=(), dtype=float32)
# tf.Tensor(4.8619576, shape=(), dtype=float32)
# tf.Tensor(4.7568455, shape=(), dtype=float32)
# tf.Tensor(4.7929792, shape=(), dtype=float32)
# tf.Tensor(5.006095, shape=(), dtype=float32)
# tf.Tensor(4.8271933, shape=(), dtype=float32)
# tf.Tensor(4.858369, shape=(), dtype=float32)
# tf.Tensor(4.805546, shape=(), dtype=float32)
# tf.Tensor(4.9879317, shape=(), dtype=float32)
# tf.Tensor(4.7301507, shape=(), dtype=float32)
# tf.Tensor(4.8279614, shape=(), dtype=float32)
# tf.Tensor(4.7613845, shape=(), dtype=float32)
# tf.Tensor(4.87185, shape=(), dtype=float32)
# tf.Tensor(4.7600636, shape=(), dtype=float32)
# tf.Tensor(4.830455, shape=(), dtype=float32)
# tf.Tensor(4.8856277, shape=(), dtype=float32)
# tf.Tensor(4.7325363, shape=(), dtype=float32)
# tf.Tensor(4.959405, shape=(), dtype=float32)
# tf.Tensor(4.856282, shape=(), dtype=float32)
# tf.Tensor(4.8593197, shape=(), dtype=float32)
# tf.Tensor(4.8772616, shape=(), dtype=float32)
# tf.Tensor(4.957215, shape=(), dtype=float32)
# tf.Tensor(4.8410716, shape=(), dtype=float32)
# tf.Tensor(4.906471, shape=(), dtype=float32)
# tf.Tensor(4.8521624, shape=(), dtype=float32)
# tf.Tensor(4.900491, shape=(), dtype=float32)
# tf.Tensor(4.8543577, shape=(), dtype=float32)
# tf.Tensor(4.824993, shape=(), dtype=float32)
# tf.Tensor(4.889093, shape=(), dtype=float32)
# tf.Tensor(4.8117228, shape=(), dtype=float32)
# tf.Tensor(4.958064, shape=(), dtype=float32)
# tf.Tensor(4.74957, shape=(), dtype=float32)
# tf.Tensor(4.821421, shape=(), dtype=float32)
# tf.Tensor(4.8251886, shape=(), dtype=float32)
# tf.Tensor(4.9788976, shape=(), dtype=float32)
# tf.Tensor(4.9248457, shape=(), dtype=float32)
# tf.Tensor(4.7627873, shape=(), dtype=float32)
# tf.Tensor(4.810175, shape=(), dtype=float32)
# tf.Tensor(4.8201284, shape=(), dtype=float32)
# tf.Tensor(4.8697443, shape=(), dtype=float32)
# tf.Tensor(4.944913, shape=(), dtype=float32)
# tf.Tensor(4.9082594, shape=(), dtype=float32)
# tf.Tensor(4.7952704, shape=(), dtype=float32)
# tf.Tensor(4.813014, shape=(), dtype=float32)
# tf.Tensor(4.860314, shape=(), dtype=float32)
# tf.Tensor(4.7960143, shape=(), dtype=float32)
# tf.Tensor(4.918854, shape=(), dtype=float32)
# tf.Tensor(4.8596663, shape=(), dtype=float32)
# tf.Tensor(4.993873, shape=(), dtype=float32)
# tf.Tensor(4.8127704, shape=(), dtype=float32)
# tf.Tensor(4.7209563, shape=(), dtype=float32)
# tf.Tensor(4.9301076, shape=(), dtype=float32)
# tf.Tensor(4.903761, shape=(), dtype=float32)
# tf.Tensor(4.8092465, shape=(), dtype=float32)
# tf.Tensor(4.924658, shape=(), dtype=float32)
# tf.Tensor(4.8706837, shape=(), dtype=float32)
# tf.Tensor(4.7717533, shape=(), dtype=float32)
# tf.Tensor(4.837464, shape=(), dtype=float32)
# tf.Tensor(4.7831383, shape=(), dtype=float32)
# tf.Tensor(4.736928, shape=(), dtype=float32)
# tf.Tensor(4.8758335, shape=(), dtype=float32)
# tf.Tensor(4.7297683, shape=(), dtype=float32)
# tf.Tensor(4.744187, shape=(), dtype=float32)
# tf.Tensor(5.0067463, shape=(), dtype=float32)
# tf.Tensor(4.9134407, shape=(), dtype=float32)
# tf.Tensor(4.708549, shape=(), dtype=float32)
# tf.Tensor(4.873731, shape=(), dtype=float32)
# tf.Tensor(4.751952, shape=(), dtype=float32)
# tf.Tensor(4.8643513, shape=(), dtype=float32)
# tf.Tensor(4.963611, shape=(), dtype=float32)
# tf.Tensor(4.7006474, shape=(), dtype=float32)
# tf.Tensor(4.8977675, shape=(), dtype=float32)
# tf.Tensor(4.8469954, shape=(), dtype=float32)
# tf.Tensor(4.6887174, shape=(), dtype=float32)
# tf.Tensor(4.825967, shape=(), dtype=float32)
# tf.Tensor(4.8864164, shape=(), dtype=float32)
# tf.Tensor(4.855549, shape=(), dtype=float32)
# tf.Tensor(4.860014, shape=(), dtype=float32)
# tf.Tensor(4.826456, shape=(), dtype=float32)
# tf.Tensor(4.914204, shape=(), dtype=float32)
# tf.Tensor(5.0046344, shape=(), dtype=float32)
# tf.Tensor(4.956201, shape=(), dtype=float32)
# tf.Tensor(4.908936, shape=(), dtype=float32)
# tf.Tensor(4.8796144, shape=(), dtype=float32)
# tf.Tensor(4.920287, shape=(), dtype=float32)
# tf.Tensor(4.9816165, shape=(), dtype=float32)
# tf.Tensor(4.8817344, shape=(), dtype=float32)
# tf.Tensor(4.698208, shape=(), dtype=float32)
# tf.Tensor(4.860413, shape=(), dtype=float32)
# tf.Tensor(4.8914657, shape=(), dtype=float32)
# tf.Tensor(4.945847, shape=(), dtype=float32)
# tf.Tensor(4.8570123, shape=(), dtype=float32)
# tf.Tensor(4.740607, shape=(), dtype=float32)
# tf.Tensor(4.9409475, shape=(), dtype=float32)
# tf.Tensor(4.7939987, shape=(), dtype=float32)
# tf.Tensor(4.918689, shape=(), dtype=float32)
# tf.Tensor(4.93248, shape=(), dtype=float32)
# tf.Tensor(4.936428, shape=(), dtype=float32)
# tf.Tensor(4.9529657, shape=(), dtype=float32)
# tf.Tensor(4.7741365, shape=(), dtype=float32)
# tf.Tensor(5.020185, shape=(), dtype=float32)
# tf.Tensor(4.9393783, shape=(), dtype=float32)
# tf.Tensor(4.9717145, shape=(), dtype=float32)
# tf.Tensor(4.8605556, shape=(), dtype=float32)
# tf.Tensor(4.94688, shape=(), dtype=float32)
# tf.Tensor(4.8544917, shape=(), dtype=float32)
# tf.Tensor(4.906167, shape=(), dtype=float32)
# tf.Tensor(4.7467537, shape=(), dtype=float32)
# tf.Tensor(4.8317914, shape=(), dtype=float32)
# tf.Tensor(4.8739343, shape=(), dtype=float32)
# tf.Tensor(4.9045124, shape=(), dtype=float32)
# tf.Tensor(4.8413568, shape=(), dtype=float32)
# tf.Tensor(4.888938, shape=(), dtype=float32)
# tf.Tensor(4.8856673, shape=(), dtype=float32)
# tf.Tensor(4.883795, shape=(), dtype=float32)
# tf.Tensor(4.897798, shape=(), dtype=float32)
# tf.Tensor(4.9432955, shape=(), dtype=float32)
# tf.Tensor(4.8797154, shape=(), dtype=float32)
# tf.Tensor(4.8501616, shape=(), dtype=float32)
# tf.Tensor(4.7061276, shape=(), dtype=float32)
# tf.Tensor(4.727601, shape=(), dtype=float32)
# tf.Tensor(4.922814, shape=(), dtype=float32)
# tf.Tensor(4.9563184, shape=(), dtype=float32)
# tf.Tensor(4.8510423, shape=(), dtype=float32)
# tf.Tensor(4.889723, shape=(), dtype=float32)
# tf.Tensor(4.8992543, shape=(), dtype=float32)
# tf.Tensor(4.7443476, shape=(), dtype=float32)
# tf.Tensor(4.817904, shape=(), dtype=float32)
# tf.Tensor(4.8400884, shape=(), dtype=float32)
# tf.Tensor(4.799411, shape=(), dtype=float32)
# tf.Tensor(4.7978697, shape=(), dtype=float32)
# tf.Tensor(4.8810477, shape=(), dtype=float32)
# tf.Tensor(4.8965254, shape=(), dtype=float32)
# tf.Tensor(4.8018126, shape=(), dtype=float32)
# tf.Tensor(4.913488, shape=(), dtype=float32)
# tf.Tensor(4.986847, shape=(), dtype=float32)
# tf.Tensor(4.670608, shape=(), dtype=float32)
# tf.Tensor(4.803956, shape=(), dtype=float32)
# tf.Tensor(4.710813, shape=(), dtype=float32)
# tf.Tensor(4.8539267, shape=(), dtype=float32)
# tf.Tensor(4.8088775, shape=(), dtype=float32)
# tf.Tensor(5.0432763, shape=(), dtype=float32)
# tf.Tensor(4.8401933, shape=(), dtype=float32)
# tf.Tensor(4.8686485, shape=(), dtype=float32)
# tf.Tensor(4.833335, shape=(), dtype=float32)
# tf.Tensor(4.948646, shape=(), dtype=float32)
# tf.Tensor(4.986488, shape=(), dtype=float32)
# tf.Tensor(4.803526, shape=(), dtype=float32)
# tf.Tensor(4.80003, shape=(), dtype=float32)
# tf.Tensor(4.8391256, shape=(), dtype=float32)
# tf.Tensor(4.888704, shape=(), dtype=float32)
# tf.Tensor(4.862763, shape=(), dtype=float32)
# tf.Tensor(4.7982492, shape=(), dtype=float32)
# tf.Tensor(4.940708, shape=(), dtype=float32)
# tf.Tensor(4.901364, shape=(), dtype=float32)
# tf.Tensor(4.7335963, shape=(), dtype=float32)
# tf.Tensor(4.9059873, shape=(), dtype=float32)
# tf.Tensor(4.795696, shape=(), dtype=float32)
# tf.Tensor(4.7565713, shape=(), dtype=float32)
# tf.Tensor(4.8236957, shape=(), dtype=float32)
# tf.Tensor(4.920944, shape=(), dtype=float32)
# tf.Tensor(4.9767265, shape=(), dtype=float32)
# tf.Tensor(4.967012, shape=(), dtype=float32)
# tf.Tensor(4.793906, shape=(), dtype=float32)
# tf.Tensor(4.8837266, shape=(), dtype=float32)
# tf.Tensor(4.883812, shape=(), dtype=float32)
# tf.Tensor(4.828959, shape=(), dtype=float32)
# tf.Tensor(4.809188, shape=(), dtype=float32)
# tf.Tensor(4.9873824, shape=(), dtype=float32)
# tf.Tensor(4.9540296, shape=(), dtype=float32)
# tf.Tensor(4.9185576, shape=(), dtype=float32)
# tf.Tensor(4.8187385, shape=(), dtype=float32)
# tf.Tensor(4.772402, shape=(), dtype=float32)
# tf.Tensor(4.7277217, shape=(), dtype=float32)
# tf.Tensor(4.9748535, shape=(), dtype=float32)
# tf.Tensor(4.7765074, shape=(), dtype=float32)
# tf.Tensor(4.905763, shape=(), dtype=float32)
# tf.Tensor(4.6726403, shape=(), dtype=float32)
# tf.Tensor(4.947631, shape=(), dtype=float32)
# tf.Tensor(4.821386, shape=(), dtype=float32)
# tf.Tensor(4.8802238, shape=(), dtype=float32)
# tf.Tensor(4.8792424, shape=(), dtype=float32)
# tf.Tensor(4.895313, shape=(), dtype=float32)
# tf.Tensor(4.965575, shape=(), dtype=float32)
# tf.Tensor(4.918489, shape=(), dtype=float32)
# tf.Tensor(4.95161, shape=(), dtype=float32)
# tf.Tensor(4.8820286, shape=(), dtype=float32)
# tf.Tensor(4.8305187, shape=(), dtype=float32)
# tf.Tensor(4.8522677, shape=(), dtype=float32)
# tf.Tensor(4.934411, shape=(), dtype=float32)
# tf.Tensor(4.785194, shape=(), dtype=float32)
# tf.Tensor(4.8333316, shape=(), dtype=float32)
# tf.Tensor(4.9913673, shape=(), dtype=float32)
# tf.Tensor(4.7821546, shape=(), dtype=float32)
# tf.Tensor(4.921614, shape=(), dtype=float32)
# tf.Tensor(4.9172907, shape=(), dtype=float32)
# tf.Tensor(4.908344, shape=(), dtype=float32)
# tf.Tensor(4.86009, shape=(), dtype=float32)
# tf.Tensor(4.785496, shape=(), dtype=float32)
# tf.Tensor(4.9756866, shape=(), dtype=float32)
# tf.Tensor(4.890096, shape=(), dtype=float32)
# tf.Tensor(4.8173194, shape=(), dtype=float32)
# tf.Tensor(4.750787, shape=(), dtype=float32)
# tf.Tensor(4.9509745, shape=(), dtype=float32)
# tf.Tensor(4.799947, shape=(), dtype=float32)
# tf.Tensor(4.829899, shape=(), dtype=float32)
# tf.Tensor(4.9177423, shape=(), dtype=float32)
# tf.Tensor(4.7573156, shape=(), dtype=float32)
# tf.Tensor(4.8470516, shape=(), dtype=float32)
# tf.Tensor(4.846506, shape=(), dtype=float32)
# tf.Tensor(4.885025, shape=(), dtype=float32)
# tf.Tensor(5.00445, shape=(), dtype=float32)
# tf.Tensor(4.8972487, shape=(), dtype=float32)
# tf.Tensor(4.804351, shape=(), dtype=float32)
# tf.Tensor(4.680244, shape=(), dtype=float32)
# tf.Tensor(4.758711, shape=(), dtype=float32)
# tf.Tensor(4.849155, shape=(), dtype=float32)
# tf.Tensor(4.9011707, shape=(), dtype=float32)
# tf.Tensor(4.8145857, shape=(), dtype=float32)
# tf.Tensor(4.8617196, shape=(), dtype=float32)
# tf.Tensor(4.9945836, shape=(), dtype=float32)
# tf.Tensor(4.90148, shape=(), dtype=float32)
# tf.Tensor(4.860024, shape=(), dtype=float32)
# tf.Tensor(4.8704853, shape=(), dtype=float32)
# tf.Tensor(4.8657618, shape=(), dtype=float32)
# tf.Tensor(4.9187865, shape=(), dtype=float32)
# tf.Tensor(4.768035, shape=(), dtype=float32)
# tf.Tensor(4.814804, shape=(), dtype=float32)
# tf.Tensor(4.8858004, shape=(), dtype=float32)
# tf.Tensor(4.7897677, shape=(), dtype=float32)
# tf.Tensor(4.8806844, shape=(), dtype=float32)
# tf.Tensor(4.7340508, shape=(), dtype=float32)
# tf.Tensor(4.604536, shape=(), dtype=float32)
# tf.Tensor(4.8686156, shape=(), dtype=float32)
# tf.Tensor(4.7299366, shape=(), dtype=float32)
# tf.Tensor(4.802472, shape=(), dtype=float32)
# tf.Tensor(4.7765126, shape=(), dtype=float32)
# tf.Tensor(4.682158, shape=(), dtype=float32)
# tf.Tensor(4.81764, shape=(), dtype=float32)
# tf.Tensor(4.8233113, shape=(), dtype=float32)
# tf.Tensor(4.8042436, shape=(), dtype=float32)
# tf.Tensor(4.811292, shape=(), dtype=float32)
# tf.Tensor(4.8319707, shape=(), dtype=float32)
# tf.Tensor(4.8017125, shape=(), dtype=float32)
# tf.Tensor(4.864277, shape=(), dtype=float32)
# tf.Tensor(4.912045, shape=(), dtype=float32)
# tf.Tensor(4.8608713, shape=(), dtype=float32)
# tf.Tensor(4.82601, shape=(), dtype=float32)
# tf.Tensor(4.77936, shape=(), dtype=float32)
# tf.Tensor(4.650028, shape=(), dtype=float32)
# tf.Tensor(4.895311, shape=(), dtype=float32)
# tf.Tensor(4.8625875, shape=(), dtype=float32)
# tf.Tensor(4.9266624, shape=(), dtype=float32)
# tf.Tensor(4.907072, shape=(), dtype=float32)
# tf.Tensor(4.709563, shape=(), dtype=float32)
# tf.Tensor(4.8691926, shape=(), dtype=float32)
# tf.Tensor(4.882349, shape=(), dtype=float32)
# tf.Tensor(4.9056835, shape=(), dtype=float32)
# tf.Tensor(4.7697287, shape=(), dtype=float32)
# tf.Tensor(4.8268933, shape=(), dtype=float32)
# tf.Tensor(4.9078064, shape=(), dtype=float32)
# tf.Tensor(4.850306, shape=(), dtype=float32)
# tf.Tensor(4.9224377, shape=(), dtype=float32)
# tf.Tensor(4.931135, shape=(), dtype=float32)
# tf.Tensor(4.775643, shape=(), dtype=float32)
# tf.Tensor(4.805288, shape=(), dtype=float32)
# tf.Tensor(4.7899785, shape=(), dtype=float32)
# tf.Tensor(4.8523426, shape=(), dtype=float32)
# tf.Tensor(4.932439, shape=(), dtype=float32)
# tf.Tensor(4.7286053, shape=(), dtype=float32)
# tf.Tensor(4.8308787, shape=(), dtype=float32)
# tf.Tensor(4.8774743, shape=(), dtype=float32)
# tf.Tensor(4.864274, shape=(), dtype=float32)
# tf.Tensor(4.6046166, shape=(), dtype=float32)
# tf.Tensor(4.6956825, shape=(), dtype=float32)
# tf.Tensor(4.869154, shape=(), dtype=float32)
# tf.Tensor(4.932977, shape=(), dtype=float32)
# tf.Tensor(4.926056, shape=(), dtype=float32)
# tf.Tensor(4.9173174, shape=(), dtype=float32)
# tf.Tensor(4.868486, shape=(), dtype=float32)
# tf.Tensor(4.7847676, shape=(), dtype=float32)
# tf.Tensor(4.619196, shape=(), dtype=float32)
# tf.Tensor(4.895892, shape=(), dtype=float32)
# tf.Tensor(4.835069, shape=(), dtype=float32)
# tf.Tensor(4.904518, shape=(), dtype=float32)
# tf.Tensor(4.784388, shape=(), dtype=float32)
# tf.Tensor(4.905835, shape=(), dtype=float32)
# tf.Tensor(4.8550534, shape=(), dtype=float32)
# tf.Tensor(4.636609, shape=(), dtype=float32)
# tf.Tensor(4.935778, shape=(), dtype=float32)
# tf.Tensor(4.961163, shape=(), dtype=float32)
# tf.Tensor(4.9074907, shape=(), dtype=float32)
# tf.Tensor(4.841648, shape=(), dtype=float32)
# tf.Tensor(4.9479933, shape=(), dtype=float32)
# tf.Tensor(4.793008, shape=(), dtype=float32)
# tf.Tensor(4.7744684, shape=(), dtype=float32)
# tf.Tensor(4.8763423, shape=(), dtype=float32)
# tf.Tensor(4.8419185, shape=(), dtype=float32)
# tf.Tensor(4.911974, shape=(), dtype=float32)
# tf.Tensor(4.7937503, shape=(), dtype=float32)
# tf.Tensor(4.94983, shape=(), dtype=float32)
# tf.Tensor(4.7283278, shape=(), dtype=float32)
# tf.Tensor(4.927706, shape=(), dtype=float32)
# tf.Tensor(4.92654, shape=(), dtype=float32)
# tf.Tensor(4.9107623, shape=(), dtype=float32)
# tf.Tensor(4.7364917, shape=(), dtype=float32)
# tf.Tensor(4.8470984, shape=(), dtype=float32)
# tf.Tensor(4.7994, shape=(), dtype=float32)
# tf.Tensor(4.864216, shape=(), dtype=float32)
# tf.Tensor(5.002903, shape=(), dtype=float32)
# tf.Tensor(4.758554, shape=(), dtype=float32)
# tf.Tensor(4.8233614, shape=(), dtype=float32)
# tf.Tensor(4.812808, shape=(), dtype=float32)
# tf.Tensor(4.840897, shape=(), dtype=float32)
# tf.Tensor(4.7296333, shape=(), dtype=float32)
# tf.Tensor(4.7802553, shape=(), dtype=float32)
# tf.Tensor(5.0288944, shape=(), dtype=float32)
# tf.Tensor(4.866234, shape=(), dtype=float32)
# tf.Tensor(4.878338, shape=(), dtype=float32)
# tf.Tensor(4.6981874, shape=(), dtype=float32)
# tf.Tensor(4.6686106, shape=(), dtype=float32)
# tf.Tensor(4.7554536, shape=(), dtype=float32)
# tf.Tensor(4.8804684, shape=(), dtype=float32)
# tf.Tensor(4.8506856, shape=(), dtype=float32)
# tf.Tensor(4.982527, shape=(), dtype=float32)
# tf.Tensor(4.8769574, shape=(), dtype=float32)
# tf.Tensor(4.825982, shape=(), dtype=float32)
# tf.Tensor(4.8911004, shape=(), dtype=float32)
# tf.Tensor(4.912816, shape=(), dtype=float32)
# tf.Tensor(4.718907, shape=(), dtype=float32)
# tf.Tensor(4.8725977, shape=(), dtype=float32)
# tf.Tensor(4.9345403, shape=(), dtype=float32)
# tf.Tensor(4.951958, shape=(), dtype=float32)
# tf.Tensor(4.826417, shape=(), dtype=float32)
# tf.Tensor(4.654098, shape=(), dtype=float32)
# tf.Tensor(4.7896166, shape=(), dtype=float32)
# tf.Tensor(4.8533773, shape=(), dtype=float32)
# tf.Tensor(4.901782, shape=(), dtype=float32)
# tf.Tensor(4.9790306, shape=(), dtype=float32)
# tf.Tensor(4.9208703, shape=(), dtype=float32)
# tf.Tensor(4.8905354, shape=(), dtype=float32)
# tf.Tensor(4.8800597, shape=(), dtype=float32)
# tf.Tensor(4.903307, shape=(), dtype=float32)
# tf.Tensor(4.8418546, shape=(), dtype=float32)
# tf.Tensor(4.728299, shape=(), dtype=float32)
# tf.Tensor(4.7679143, shape=(), dtype=float32)
# tf.Tensor(4.912777, shape=(), dtype=float32)
# tf.Tensor(4.8831816, shape=(), dtype=float32)
# tf.Tensor(4.8912444, shape=(), dtype=float32)
# tf.Tensor(4.8401995, shape=(), dtype=float32)
# tf.Tensor(4.731696, shape=(), dtype=float32)
# tf.Tensor(4.8246107, shape=(), dtype=float32)
# tf.Tensor(4.78618, shape=(), dtype=float32)
# tf.Tensor(4.8003383, shape=(), dtype=float32)
# tf.Tensor(4.8357663, shape=(), dtype=float32)
# tf.Tensor(4.745401, shape=(), dtype=float32)
# tf.Tensor(4.851018, shape=(), dtype=float32)
# tf.Tensor(4.836944, shape=(), dtype=float32)
# tf.Tensor(4.7584033, shape=(), dtype=float32)
# tf.Tensor(4.8806853, shape=(), dtype=float32)
# tf.Tensor(4.892225, shape=(), dtype=float32)
# tf.Tensor(4.853638, shape=(), dtype=float32)
# tf.Tensor(4.795541, shape=(), dtype=float32)
# tf.Tensor(4.837153, shape=(), dtype=float32)
# tf.Tensor(4.915795, shape=(), dtype=float32)
# tf.Tensor(4.897999, shape=(), dtype=float32)
# tf.Tensor(4.7917686, shape=(), dtype=float32)
# tf.Tensor(5.0076084, shape=(), dtype=float32)
# tf.Tensor(4.917996, shape=(), dtype=float32)
# tf.Tensor(4.8096266, shape=(), dtype=float32)
# tf.Tensor(4.912039, shape=(), dtype=float32)
# tf.Tensor(4.8649154, shape=(), dtype=float32)
# tf.Tensor(4.9528446, shape=(), dtype=float32)
# tf.Tensor(4.7310085, shape=(), dtype=float32)
# tf.Tensor(4.8009415, shape=(), dtype=float32)
# tf.Tensor(4.8469987, shape=(), dtype=float32)
# tf.Tensor(4.8324776, shape=(), dtype=float32)
# tf.Tensor(4.8674145, shape=(), dtype=float32)
# tf.Tensor(4.9144893, shape=(), dtype=float32)
# tf.Tensor(4.777867, shape=(), dtype=float32)
# tf.Tensor(4.825274, shape=(), dtype=float32)
# tf.Tensor(4.821235, shape=(), dtype=float32)
# tf.Tensor(4.790971, shape=(), dtype=float32)
# tf.Tensor(4.7594323, shape=(), dtype=float32)
# tf.Tensor(4.8457575, shape=(), dtype=float32)
# tf.Tensor(4.7625947, shape=(), dtype=float32)
# tf.Tensor(4.8127036, shape=(), dtype=float32)
# tf.Tensor(4.853448, shape=(), dtype=float32)
# tf.Tensor(4.8980536, shape=(), dtype=float32)
# tf.Tensor(4.794543, shape=(), dtype=float32)
# tf.Tensor(4.8193045, shape=(), dtype=float32)
# tf.Tensor(4.7921796, shape=(), dtype=float32)
# tf.Tensor(4.8240542, shape=(), dtype=float32)
# tf.Tensor(4.8000016, shape=(), dtype=float32)
# tf.Tensor(4.9142814, shape=(), dtype=float32)
# tf.Tensor(4.7862453, shape=(), dtype=float32)
# tf.Tensor(4.901097, shape=(), dtype=float32)
# tf.Tensor(4.8304663, shape=(), dtype=float32)
# tf.Tensor(4.7692637, shape=(), dtype=float32)
# tf.Tensor(4.8776526, shape=(), dtype=float32)
# tf.Tensor(5.012303, shape=(), dtype=float32)
# tf.Tensor(4.7550516, shape=(), dtype=float32)
# tf.Tensor(4.84191, shape=(), dtype=float32)
# tf.Tensor(4.8407063, shape=(), dtype=float32)
# tf.Tensor(4.919403, shape=(), dtype=float32)
# tf.Tensor(4.872785, shape=(), dtype=float32)
# tf.Tensor(4.8314323, shape=(), dtype=float32)
# tf.Tensor(4.920199, shape=(), dtype=float32)
# tf.Tensor(4.7181597, shape=(), dtype=float32)
# tf.Tensor(4.7636805, shape=(), dtype=float32)
# tf.Tensor(4.7549906, shape=(), dtype=float32)
